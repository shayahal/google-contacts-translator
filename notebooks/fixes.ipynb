# %%
import pandas as pd

df = pd.read_csv('../translated_contacts.csv')
only_hebrew = df[df['English Name'].isna()]

# %%
only_hebrew.to_csv('only_hebrew.csv', index=False)

# %%
only_hebrew
# Out:
#      English Name                   Hebrew Name                     Email  \
# 1022          NaN          נעמה ארבילי אח"ם י"ב  naama.arbili75@gmail.com
# 1023          NaN              נעמה מעוז ביס כד          maozn9@gmail.com
# 1024          NaN  נעמה מתווכת מתעניינת בגוטליב                       NaN
# 1025          NaN                  נעמה סדובסקי                       NaN
# 1026          NaN               נעמה פינקלשטיין                       NaN
# ...           ...                           ...                       ...
# 1421          NaN                     תמיר- רספ                       NaN
# 1422          NaN                  תמר כהן הגנה                       NaN
# 1423          NaN                      תמר שכטר                       NaN
# 1424          NaN                      תמר תבור                       NaN
# 1425          NaN         תמרה גיידר מועמדת לDS                       NaN
#
#                  Phone  Google Contact ID
# ...
